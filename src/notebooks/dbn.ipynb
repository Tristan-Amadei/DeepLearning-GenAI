# %%
import sys
sys.path.append('..')

from dbn import DBN
from load_data import lire_alpha_digits

# %% [markdown]
# ## Load Binary AlphaDigits

# %%
binary_alpha = lire_alpha_digits(['A', 'E', '4'])

# %% [markdown]
# ## Deep Belied Network

# %%
dbn_model = DBN(X=binary_alpha, L=3, qs=[1000, 500, 250])

# %%
dbn_model.train_DBN(epochs=1500, learning_rate=1e-3, batch_size=32)
# Out:
# 100%|██████████| 3/3 [02:49<00:00, 56.38s/it]

# %%
_ = dbn_model.generer_image_DBN(num_samples=20, gibbs_steps=1000, ncols=10, image_size=(20, 16))
