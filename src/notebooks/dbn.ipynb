# %%
import sys
sys.path.append('..')

from dbn import DBN
from load_data import lire_alpha_digits, load_mnist

# %% [markdown]
# ## Binary AlphaDigits

# %%
binary_alpha = lire_alpha_digits(['A', 'E', '4'])

# %% [markdown]
# ### Deep Belied Network - SGD

# %%
dbn_model = DBN(X=binary_alpha, L=3, qs=[256, 512, 256], use_adam=False)

# %%
dbn_model.train_DBN(epochs=5000, learning_rate=1e-3, batch_size=128)
# Out:
# RBM 2: 100%|██████████| 3/3 [01:42<00:00, 34.20s/rbm, total_loss=0.0392]

# %%
_ = dbn_model.generer_image_DBN(num_samples=20, gibbs_steps=1000, ncols=10, image_size=(20, 16))

# %% [markdown]
# ### Deep Belied Network - Adam

# %%
dbn_model = DBN(X=binary_alpha, L=3, qs=[256, 512, 256], use_adam=True)

# %%
dbn_model.train_DBN(epochs=5000, learning_rate=1e-3, batch_size=128)
# Out:
# RBM 2: 100%|██████████| 3/3 [02:39<00:00, 53.08s/rbm, total_loss=0.0449]

# %%
_ = dbn_model.generer_image_DBN(num_samples=20, gibbs_steps=1000, ncols=10, image_size=(20, 16))

# %% [markdown]
# ## MNIST

# %%
X_train, y_train, X_test, y_test = load_mnist()

# %%
dbn_model = DBN(X=X_test, L=5, qs=[256, 512, 1024, 512, 256])

# %%
dbn_model.train_DBN(epochs=500, learning_rate=1e-3, batch_size=512)
# Out:
# ...
# 100%|██████████| 5/5 [53:16<00:00, 639.28s/it]

# %%
_ = dbn_model.generer_image_DBN(num_samples=20, gibbs_steps=5000, ncols=10, image_size=(28, 28))
